# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Histograms

# %%
psi_sst = np.random.normal(25,10,10000)
psi_lmt = np.random.normal(10,5,10000)

# %%
plt.plot(psi_sst,psi_lmt)

# %%
plt.hist(psi_sst)
# Out:
# (array([   9.,   83.,  448., 1297., 2473., 2848., 1859.,  771.,  179.,
#           33.]),
#  array([-12.95937109,  -5.66550855,   1.62835399,   8.92221653,
#          16.21607907,  23.50994161,  30.80380415,  38.09766669,
#          45.39152923,  52.68539177,  59.97925431]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(psi_lmt)
# Out:
# (array([2.500e+01, 1.750e+02, 9.850e+02, 2.284e+03, 3.108e+03, 2.300e+03,
#         9.060e+02, 2.000e+02, 1.500e+01, 2.000e+00]),
#  array([-8.24985612, -4.16990551, -0.08995491,  3.98999569,  8.0699463 ,
#         12.1498969 , 16.2298475 , 20.30979811, 24.38974871, 28.46969931,
#         32.54964992]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(psi_sst)
plt.hist(psi_lmt)
# Out:
# (array([2.500e+01, 1.750e+02, 9.850e+02, 2.284e+03, 3.108e+03, 2.300e+03,
#         9.060e+02, 2.000e+02, 1.500e+01, 2.000e+00]),
#  array([-8.24985612, -4.16990551, -0.08995491,  3.98999569,  8.0699463 ,
#         12.1498969 , 16.2298475 , 20.30979811, 24.38974871, 28.46969931,
#         32.54964992]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(psi_sst, label = 'Sandstone Porosity(%)')
plt.hist(psi_lmt,alpha=0.5, label = 'Limestone Porosity(%)')
plt.legend()

# %%
plt.hist(psi_sst, label = 'Sandstone Porosity(%)',bins=100)
# Out:
# (array([  1.,   0.,   0.,   1.,   2.,   1.,   0.,   0.,   0.,   4.,   8.,
#           5.,   3.,   4.,   4.,  14.,  11.,  13.,  12.,   9.,  24.,  29.,
#          23.,  31.,  44.,  59.,  50.,  55.,  63.,  70.,  84.,  80.,  89.,
#         136., 121., 111., 157., 163., 173., 183., 187., 208., 221., 227.,
#         260., 261., 278., 284., 274., 273., 275., 278., 309., 307., 292.,
#         300., 277., 284., 274., 252., 219., 240., 223., 208., 178., 202.,
#         165., 156., 139., 129., 134., 107.,  79.,  97.,  87.,  66.,  52.,
#          49.,  49.,  51.,  34.,  30.,  26.,  27.,  16.,  10.,   9.,   4.,
#          17.,   6.,   6.,   8.,   8.,   0.,   4.,   1.,   4.,   1.,   0.,
#           1.]),
#  array([-12.95937109, -12.22998483, -11.50059858, -10.77121232,
#         -10.04182607,  -9.31243982,  -8.58305356,  -7.85366731,
#          -7.12428105,  -6.3948948 ,  -5.66550855,  -4.93612229,
#          -4.20673604,  -3.47734978,  -2.74796353,  -2.01857728,
#          -1.28919102,  -0.55980477,   0.16958149,   0.89896774,
#           1.62835399,   2.35774025,   3.0871265 ,   3.81651276,
#           4.54589901,   5.27528526,   6.00467152,   6.73405777,
#           7.46344403,   8.19283028,   8.92221653,   9.65160279,
#          10.38098904,  11.11037529,  11.83976155,  12.5691478 ,
#          13.29853406,  14.02792031,  14.75730656,  15.48669282,
#          16.21607907,  16.94546533,  17.67485158,  18.40423783,
#          19.13362409,  19.86301034,  20.5923966 ,  21.32178285,
#          22.0511691 ,  22.78055536,  23.50994161,  24.23932787,
#          24.96871412,  25.69810037,  26.42748663,  27.15687288,
#          27.88625914,  28.61564539,  29.34503164,  30.0744179 ,
#          30.80380415,  31.53319041,  32.26257666,  32.99196291,
#          33.72134917,  34.45073542,  35.18012168,  35.90950793,
#          36.63889418,  37.36828044,  38.09766669,  38.82705295,
#          39.5564392 ,  40.28582545,  41.01521171,  41.74459796,
#          42.47398422,  43.20337047,  43.93275672,  44.66214298,
#          45.39152923,  46.12091549,  46.85030174,  47.57968799,
#          48.30907425,  49.0384605 ,  49.76784676,  50.49723301,
#          51.22661926,  51.95600552,  52.68539177,  53.41477803,
#          54.14416428,  54.87355053,  55.60293679,  56.33232304,
#          57.0617093 ,  57.79109555,  58.5204818 ,  59.24986806,
#          59.97925431]),
#  <BarContainer object of 100 artists>)

# %%
plt.hist(psi_sst, label = 'Sandstone Porosity(%)', bins=25)
# Out:
# (array([   2.,    3.,   17.,   25.,   45.,  107.,  208.,  297.,  457.,
#          676.,  843., 1083., 1100., 1208., 1087.,  890.,  701.,  509.,
#          329.,  201.,  117.,   39.,   37.,   13.,    6.]),
#  array([-12.95937109, -10.04182607,  -7.12428105,  -4.20673604,
#          -1.28919102,   1.62835399,   4.54589901,   7.46344403,
#          10.38098904,  13.29853406,  16.21607907,  19.13362409,
#          22.0511691 ,  24.96871412,  27.88625914,  30.80380415,
#          33.72134917,  36.63889418,  39.5564392 ,  42.47398422,
#          45.39152923,  48.30907425,  51.22661926,  54.14416428,
#          57.0617093 ,  59.97925431]),
#  <BarContainer object of 25 artists>)

# %%
bins = [10,30,300]

for i in bins: 
    plt.hist(psi_sst,label="Sandstone",bins = i)
    plt.show()

# %% [markdown]
# #  Subplots:Multiple plots next to each other

# %%
plt.subplots(nrows=2,ncols=2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
x_data = np.linspace(1,100,1000)

# %%
fig, axs = plt.subplots(nrows=2,ncols=2)

fig.set_figheight(10) ; fig.set_figwidth(16)

axs[0,0].plot(x_data,x_data**1,label="Power 1")
axs[0,0].set_title("Power = 1")
axs[0,0].grid()


axs[0,1].plot(x_data,x_data**2,label="Power 2")
axs[0,1].set_title("Power = 2")
axs[0,1].grid()

axs[1,0].plot(x_data,x_data**3,label="Power 3")
axs[1,0].set_title("Power = 3")
axs[1,0].grid()
 



axs[1,1].hist(psi_sst, label = 'Sandstone Porosity(%)')
axs[1,1].hist(psi_lmt, label = 'LMT Porosity(%)')
axs[1,1].set_title("Histogram of porosities")
axs[1,1].grid()

fig.tight_layout()

# %% [markdown]
# # Klinkenberg Effect

# %%
import IPython.display
from IPython.display import Image

# %%
Image("C:\\Users\\habib\\\Downloads\\download.png")

# %%
Image("C:\\Users\\habib\\\Downloads\\download(1).png")

# %%
Image("C:\\Users\\habib\\\Downloads\\download(2).png")

# %%
k = float(input('Enter the initisl guess of absolute Permeability(md): '))
pmean = float(input('Enter the mean pressure(psi): '))
kgas = float(input('Enter the gas perm. (md): '))
# Out:
# Enter the initisl guess of absolute Permeability(md): 51
# Enter the mean pressure(psi): 51
# Enter the gas perm. (md): 52

# %%
while abs(6.9*(k**0.64)+pmean*k-pmean*kgas) >0.0001:
    k = k - (6.9*(k**0.64)+pmean*k - pmean*kgas)/(4.416*(k**(-0.36))+pmean)

# %%
print("The value of absolute permeability after iteration or gas permeability at infinite pmean is ",k)
# Out:
# The value of absolute permeability after iteration or gas permeability at infinite pmean is  50.33851969973379

# %%
x = [0,1/pmean]
y = [k,kgas]

# %%
plt.style.use('classic')

plt.figure(figsize=(8,4))

plt.plot(x,y)

plt.xlabel('1/Mean_Pressure (psi^-1)')

plt.ylabel('Perm')

plt.title('Klinkenberg Effect')

plt.grid(True)

# %%
x,y
# Out:
# ([0, 0.0196078431372549], [50.33851969973379, 52.0])

# %%
coefficients = np.polyfit(x,y,1)

# %%
x_axis = np.linspace(0,0.5,200)

# %%
y_axis = coefficients[0]*x_axis + coefficients[1]

# %%
plt.figure(figsize=(16,8))
plt.plot(x_axis,y_axis,label = 'Extrapolated Line')
plt.plot(x,y,label = 'Original Line')

plt.xlabel('1/Mean_pressure (psi^-1)')
plt.ylabel('PERM.')
plt.title('Klinkenberg Effect')
plt.grid(True)
plt.legend()

# %%
def klinkenberg():
    #Take input from user
    k = float(input('Enter the initisl guess of absolute Permeability(md): '))
    pmean = float(input('Enter the mean pressure(psi): '))
    kgas = float(input('Enter the gas perm. (md): '))
    
    #pmean_for_new_perm = float(input('Enter the mean pressure(psi) at which permeability need to be found: '))
    
    # Find Kl
    while abs(6.9*(k**0.64)+pmean*k-pmean*kgas) >0.0001:
        k = k - (6.9*(k**0.64)+pmean*k - pmean*kgas)/(4.416*(k**(-0.36))+pmean)
    
    print("The value of absolute permeability after iteration or gas permeability at infinite pmean is ",k)
    
    # GIVEN DATA POIUNTS
    x = [0,1/pmean]
    y = [k,kgas]
    
    # Extrapolated Data
    
    coefficients = np.polyfit(x,y,1)
    x_axis = np.linspace(0,0.5,200)
    y_axis = coefficients[0]*x_axis + coefficients[1]
    
    #Final plot
    
    plt.figure(figsize=(16,8))
    plt.plot(x_axis,y_axis,label = 'Extrapolated Line')
    plt.plot(x,y,label = 'Original Line')
    
    #plt.scatter(0.3,24,label = 'scatter',s = 100,c='red',marker= "+")
    plt.xlabel('1/Mean_pressure (psi^-1)')
    plt.ylabel('PERM.')
    plt.title('Klinkenberg Effect')
    plt.grid(True)
    plt.legend()
    
    return k

# %%
klinkenberg()
# Out:
# Enter the initisl guess of absolute Permeability(md): 45
# Enter the mean pressure(psi): 52
# Enter the gas perm. (md): 541
# The value of absolute permeability after iteration or gas permeability at infinite pmean is  533.6163283130305
# 533.6163283130305

# %% [markdown]
# # Home Assignment 1
# #### Add functionality, user will provide input of mean pressure, calculate the gas permeability at given pmean, and also plot that scatter in this figure

# %% [markdown]
# # Pressure Profiling Reservoir

# %%
Image("C:\\Users\\habib\\\Downloads\\download3.png")

# %%
re = float(input('Outer radius of Reservoir(ft): '))
rw = float(input('Wellbore Radius(ft): '))
Pwf = float(input('Bottomhole Pressure(PSI): '))
h = float(input('Net Pay Thickness(ft): '))
k = float(input('Average Reservoir Permeability(mD): '))
q = float(input('Flowrate(STB/Day): '))
mu = float(input('Oil Viscosity: '))
plt.grid(True)

# %% [markdown]
# # Home Assignment 1
# #### Add functionality, user will provide input of mean pressure, calculate the gas permeability at given pmean, and also plot that scatter in this figure

# %%
def klinkenberg():
    #Take input from user
    k = float(input('Enter the initisl guess of absolute Permeability(md): '))
    pmean = float(input('Enter the mean pressure(psi): '))
    kgas = float(input('Enter the gas perm. (md): '))
    
    #pmean_for_new_perm = float(input('Enter the mean pressure(psi) at which permeability need to be found: '))
    
    # Find Kl
    while abs(6.9*(k**0.64)+pmean*k-pmean*kgas) >0.0001:
        k = k - (6.9*(k**0.64)+pmean*k - pmean*kgas)/(4.416*(k**(-0.36))+pmean)
    
    print("The value of absolute permeability after iteration or gas permeability at infinite pmean is ",k)
    
    # GIVEN DATA POIUNTS
    x = [0,1/pmean]
    y = [k,kgas]
    
    # Extrapolated Data
    
    coefficients = np.polyfit(x,y,1)
    x_axis = np.linspace(0,0.5,200)
    y_axis = coefficients[0]*x_axis + coefficients[1]
    
    #Final plot
    
    plt.figure(figsize=(16,8))
    plt.plot(x_axis,y_axis,label = 'Extrapolated Line')
    plt.plot(x,y,label = 'Original Line')
    
    #plt.scatter(0.3,24,label = 'scatter',s = 100,c='red',marker= "+")

    plt.xlabel('1/Mean_pressure (psi^-1)')
    plt.ylabel('PERM.')
    plt.title('Klinkenberg Effect')
    plt.grid(True)
    plt.legend()
    
    return k

# %%
klinkenberg()
# Out:
# Enter the initisl guess of absolute Permeability(md): 200
# Enter the mean pressure(psi): 30
# Enter the gas perm. (md): 10
# The value of absolute permeability after iteration or gas permeability at infinite pmean is  9.057638700759204
# 9.057638700759204

# %%
k = float(input('Enter the initisl guess of absolute Permeability(md): '))
pmean = float(input('Enter the mean pressure(psi): '))
kgas = float(input('Enter the gas perm. (md): '))
# Out:
# Enter the initisl guess of absolute Permeability(md): 50
# Enter the mean pressure(psi): 30
# Enter the gas perm. (md): 25

# %%
while abs(6.9*(k**0.64)+pmean*k-pmean*kgas) >0.0001:
    k = k - (6.9*(k**0.64)+pmean*k - pmean*kgas)/(4.416*(k**(-0.36))+pmean)

# %%
print("The value of absolute permeability after iteration or gas permeability at infinite pmean is ",k)
# Out:
# The value of absolute permeability after iteration or gas permeability at infinite pmean is  23.275954831821117

# %%
x = [0,1/pmean]
y = [k,kgas]

# %%
plt.style.use('classic')

plt.figure(figsize=(8,4))

plt.plot(x,y)

plt.xlabel('1/Mean_Pressure (psi^-1)')

plt.ylabel('Perm')
plt.title('Klinkenberg Effect')

plt.grid(True)

# %%
x,y
# Out:
# ([0, 0.03333333333333333], [23.275954831821117, 25.0])

# %%
coefficients = np.polyfit(x,y,1)

# %%
x_axis = np.linspace(0,0.5,200)

# %%
y_axis = coefficients[0]*x_axis + coefficients[1]

# %%
plt.figure(figsize=(16,8))
plt.plot(x_axis,y_axis,label = 'Extrapolated Line')
plt.plot(x,y,label = 'Original Line')

plt.xlabel('1/Mean_pressure (psi^-1)')
plt.ylabel('PERM.')
plt.scatter(0.03,23.27)
plt.title('Klinkenberg Effect')
plt.grid(True)
plt.legend()
