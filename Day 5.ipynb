 0.5908212740863384,
 0.5048006309152495,
 0.004507270118871309,
 0.3857935757138101,
 0.8201996698608346,
 0.35513077211863364,
 0.7031907227237468,
 0.09391600626531971,
 0.6629688448732765,
 0.6865582612545074,
 0.028826525011124482,
 0.0032863121598167844,
 0.9424358915205538,
 0.2697835774611832,
 0.605798039753399,
 0.8098564542369057,
 0.3920621155871976,
 0.06744332609134529,
 0.9335141765129126,
 0.47781027427784184,
 0.4037662607123518,
 0.5946160486387443,
 0.9822934837216875,
 0.07566417273177228,
 0.848712780990342,
 0.8801742105196753,
 0.8278043447973213,
 0.9351267903704498,
 0.009871280634617063,
 0.7314978469622267,
 0.6294732743307979,
 0.29974173757404143,
 0.6281104876979801,
 0.30382939933798647,
 0.6418076963215122,
 0.7786602277122728,
 0.7715268806955234,
 0.40253531976576706,
 0.488307671547885,
 0.3583626805492893,
 0.4895657619341749,
 0.728556881627505,
 0.5380064666481457,
 0.5786499943803771,
 0.9291547183030364,
 0.6429931147232217,
 0.22972486187779229,
 0.41752648824950556,
 0.0077293430890489345,
 0.18356606003533682,
 0.6270785524464824,
 0.04633942687740433,
 0.06479846350693375,
 0.5422194270321055,
 0.46725356942327856]

# %%
api_gravity=[]
for i in specific_gravity:
    api=(141.5/i)-131.5
    print(f'API gravity corresponding to specific gravity {i} is {api}')
    api_gravity.append(api)
# Out:
# API gravity corresponding to specific gravity 0.2462309560552275 is 443.1637314288897
# API gravity corresponding to specific gravity 0.9662207830254402 is 14.946860268244052
# API gravity corresponding to specific gravity 0.5524539408988589 is 124.62994952986543
# API gravity corresponding to specific gravity 0.614024611141721 is 98.94678899253574
# API gravity corresponding to specific gravity 0.7238818518327202 is 63.973887958029394
# API gravity corresponding to specific gravity 0.1773096036861831 is 666.5391194739692
# API gravity corresponding to specific gravity 0.43563289239787384 is 193.31477516799788
# API gravity corresponding to specific gravity 0.2459465516821927 is 443.82825336312715
# API gravity corresponding to specific gravity 0.6945663765969559 is 72.22422963127374
# API gravity corresponding to specific gravity 0.6443078252880563 is 88.11552296332636
# API gravity corresponding to specific gravity 0.13558937836020268 is 912.0920697570818
# ...

# %%
api_gravity
# Out:
# [443.1637314288897,
#  14.946860268244052,
#  124.62994952986543,
#  98.94678899253574,
#  63.973887958029394,
#  666.5391194739692,
#  193.31477516799788,
#  443.82825336312715,
#  72.22422963127374,
#  88.11552296332636,
#  912.0920697570818,
#  1267.9872109810856,
#  249.3768700923285,
#  39.47491051111493,
#  165.04852143880856,
#  45.64150890090147,
#  814.1338656706419,
#  621.543116172964,
#  6281.370738082419,
#  343.1699411210181,
#  422.4865219846706,
#  132.8557899523421,
#  192.4114150629223,
#  90.17777158854588,
#  792.0515826835942,
#  29.63208667604235,
#  4017.273395642983,
#  2633.675125216325,
#  263.4399071730034,
#  134.09935181151081,
#  238.15130246729888,
#  543.0669150019693,
#  45.1728334460245,
#  337.79020889247914,
#  1194.62435074634,
#  117.10668315575793,
#  485.8304701180899,
#  519.2764915849749,
#  28.172695266614852,
#  68.64979221627357,
#  158.86740626218273,
#  3345.5530666409422,
#  588.7620062698219,
#  32.47269640016887,
#  674.910357386253,
# ...

# %% [markdown]
# # ZIP
# - zip will creat tuple from multiple interables, iterate on multiple iterables
# - min no of any value is total no of iteration

# %%
specific_gravity =(0.2,0.3,0.4,0.5,0.78,0.9,0.2)
perm = [1,2,3,4,5,6,8,98,89,5,45,545,625]

# %%
print('specific gravity is x, and my permeability is y')
# Out:
# specific gravity is x, and my permeability is y

# %%
zip(specific_gravity,perm)

# %%
list(zip(specific_gravity,perm))
# Out:
# [(0.2, 1), (0.3, 2), (0.4, 3), (0.5, 4), (0.78, 5), (0.9, 6), (0.2, 8)]

# %%
a ={.1,.22,.24,.2,.8,.2,.8,.5,.8,.2,.335,.8,.5,.5}

# %%
a
# Out:
# {0.1, 0.2, 0.22, 0.24, 0.335, 0.5, 0.8}

# %%
for i in a:
    print(i)
    print('habib')
    print(f'a percentage is {i*100}' )
    print('kakar')
print('TPS')
# Out:
# 0.1
# habib
# a percentage is 10.0
# kakar
# 0.24
# habib
# a percentage is 24.0
# kakar
# 0.22
# habib
# a percentage is 22.0
# kakar
# 0.8
# habib
# a percentage is 80.0
# kakar
# 0.2
# habib
# a percentage is 20.0
# kakar
# 0.5
# habib
# a percentage is 50.0
# kakar
# 0.335
# habib
# a percentage is 33.5
# kakar
# TPS

# %%
i
# Out:
# 0.335

# %%
a='habib'
print(f'value of a is {a}')
# Out:
# value of a is habib

# %%
for swapnil,saravana in zip(specific_gravity,perm):
    print(f'specific gravity is {swapnil} and perm is {saravana}')
# Out:
# specific gravity is 0.2 and perm is 1
# specific gravity is 0.3 and perm is 2
# specific gravity is 0.4 and perm is 3
# specific gravity is 0.5 and perm is 4
# specific gravity is 0.78 and perm is 5
# specific gravity is 0.9 and perm is 6
# specific gravity is 0.2 and perm is 8

# %%
perm=[1,2,3]
f_name=['habib','khan','kakar']
porosity=[0.2,0.3,0.4]

# %%
zip(perm,f_name,porosity)

# %%
list(zip(perm,f_name,porosity))
# Out:
# [(1, 'habib', 0.2), (2, 'khan', 0.3), (3, 'kakar', 0.4)]

# %%
for i,j,k in zip(perm,f_name,porosity):
    print(f'in field {j}, porosity {k}, and permeability is {i}')
# Out:
# in field habib, porosity 0.2, and permeability is 1
# in field khan, porosity 0.3, and permeability is 2
# in field kakar, porosity 0.4, and permeability is 3

# %%
list(zip(perm,f_name,porosity))
# Out:
# [(1, 'habib', 0.2), (2, 'khan', 0.3), (3, 'kakar', 0.4)]

# %%
rock={'field':[],'porosity':[],'permeability':[]}

# %%
for i,j,k in zip(perm,f_name,porosity):
    rock['permeability'].append(i)
    rock['field'].append(j)
    rock['porosity'].append(k)

# %%
rock
# Out:
# {'field': ['habib', 'khan', 'kakar'],
#  'porosity': [0.2, 0.3, 0.4],
#  'permeability': [1, 2, 3]}

# %%
rock={'field':f_name,"porosity":porosity,'permeability':perm}

# %%
rock
# Out:
# {'field': ['habib', 'khan', 'kakar'],
#  'porosity': [0.2, 0.3, 0.4],
#  'permeability': [1, 2, 3]}

# %% [markdown]
# # If - else : to run a block of code if a certain condition holds true
# - identation : spaces at the beginning  of a code line

# %%
a=2

# %%
if a>3:
    print('a is greater than 3')
else:
    print('a is not greater than 3')
# Out:
# a is not greater than 3

# %%
if a>3:
    print('habib')

# %%
else:
    print('kakar')
# Out:
#   Cell In[74], line 1
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
if 5<2:
    print('kakar')
    print('lie')
else:
    print('habib')
print('now i am out side')
# Out:
# habib
# now i am out side

# %%
5>3
# Out:
# True

# %%
if False:
    print('always be executed')

# %%
if True:
    print('kakar')
# Out:
# kakar

# %%
if True:
    print('fdkjfkdj')
else:
    print('kakaa')
# Out:
# fdkjfkdj

# %%
fdkjfkdj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 fdkjfkdj
#
# NameError: name 'fdkjfkdj' is not defined

# %%
and, or
# Out:
#   Cell In[104], line 1
#     and, or
#     ^
# SyntaxError: invalid syntax

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
reservoir_pressure = float(input('enter the reservoir pressure(psi): '))
hydrostatic_pressure = float(input('enter the hydrostatic pressure of mud(psi): '))
fracture_pressure = float(input('enter the fracture pressure of rock(psi): '))
# Out:
# enter the reservoir pressure(psi): 1200
# enter the hydrostatic pressure of mud(psi): 1600
# enter the fracture pressure of rock(psi): 1400

# %%
if hydrostatic_pressure>reservoir_pressure and hydrostatic_pressure<fracture_pressure:
    print('reservoir pressure is lesser than hydrostatic pressure, so no kick')
    print('hydrostatic pressure due to mud is lesser than fracture pressure, so no formation fractures')
    print('safe zone')
elif  hydrostatic_pressure>reservoir_pressure and hydrostatic_pressure>fracture_pressure:
    print('hydrostatic pressure is greater than fracture pressure, may result in fracture')
    print('ALERT!!! Risk of Formation fractures')
else:
    print('ALERT!!! Risk of kick')
# Out:
# hydrostatic pressure is greater than fracture pressure, may result in fracture
# ALERT!!! Risk of Formation fractures

# %%
reservoir_pressure = float(input('enter the reservoir pressure(psi): '))
hydrostatic_pressure = float(input('enter the hydrostatic pressure of mud(psi): '))
fracture_pressure = float(input('enter the fracture pressure of rock(psi): '))
if hydrostatic_pressure>reservoir_pressure and hydrostatic_pressure<fracture_pressure:
    print('reservoir pressure is lesser than hydrostatic pressure, so no kick')
    print('hydrostatic pressure due to mud is lesser than fracture pressure, so no formation fractures')
    print('safe zone')
elif  hydrostatic_pressure>reservoir_pressure and hydrostatic_pressure>fracture_pressure:
    print('hydrostatic pressure is greater than fracture pressure, may result in fracture')
    print('ALERT!!! Risk of Formation fractures')
else:
    print('ALERT!!! Risk of kick')

# %% [markdown]
# ## Assignment

# %%
## take input of reservoir pressure and bubble point pressure, whether your reservoir is undersaturated or saturated

# %%
reservoir_pressure = float(input('enter the reservoir pressure(psi): '))
bubble_point_pressure = float(input('enter the bubble point pressure (psi): '))
if reservoir_pressure>bubble_point_pressure:
    print('Undersaturated reservoir')
elif reservoir_pressure<bubble_point_pressure:
    print('saturated reservoir')
else:
    print('Gas and oil is present')
